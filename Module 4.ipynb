# %% [markdown]
# #1 What is file function? What is keywords to create and write file.
# Ans - Python file object provides methods and attributes to access and manipulate files. Using file objects, we can read or write any files.
#
# Whenever we open a file to perform any operations on it, Python returns a file object. To create a file object in Python use the built-in functions.
#
#
# Python has a built-in open() function to open a file. This function returns a file object, also called a handle, as it is used to read or modify the file accordingly. We can specify the mode while opening a file. In mode, we specify whether we want to read r , write w or append a to the file.

# %%
#2 Write program to read an entire text file.
file_object = open("mytextfile.txt", 'w')
file_object.write('hello, this is file handling.')
file_object.close()
file_object = open("mytextfile.txt", 'r')
print(file_object.readlines())
# Out:
# ['hello, this is file handling.']

# %%
#3 Write a python program to append text to a file and display the text.
file_object = open("file.txt", 'w')
file_object.write('Hello Everyone  ')
file_object.close()
file_object = open("file.txt", 'a')
file_object.write('welcome to world')
file_object.close()
file_object = open('file.txt','r')
print(file_object.read())
# Out:
# Hello Everyone  welcome to world

# %%
#4 Program to read first n lines of a file.
file_object = open("file.txt", 'w')
file_object.writelines('Hello \n Everyone \n welcome \n to \n tops\n')
file_object.close()
file_object = open("file.txt", 'r')
print(file_object.read(5))
# Out:
# Hello

# %%
#5 Program to read last n lines of a file.
file_object = open("file.txt", 'w')
file_object.writelines('Hello \n Everyone \n welcome \n to \n tops\n')
file_object.close()
file_object = open("file.txt", 'r')
print(file_object.readlines()[-1])
# Out:
#  tops

# %%
#6 Write a python program to read a file line by line and store it into a list.
file_object = open("file.txt", 'w')
file_object.writelines('Hello \n Everyone \n welcome \n to \n tops\n')
file_object.close()
file_object = open("file.txt", 'r')
f = file_object.read()
print(f)

l = []
for i in f:
  
  l += i

print(l)
# Out:
# Hello
#  Everyone
#  welcome
#  to
#  tops
#
# ['H', 'e', 'l', 'l', 'o', ' ', '\n', ' ', 'E', 'v', 'e', 'r', 'y', 'o', 'n', 'e', ' ', '\n', ' ', 'w', 'e', 'l', 'c', 'o', 'm', 'e', ' ', '\n', ' ', 't', 'o', ' ', '\n', ' ', 't', 'o', 'p', 's', '\n']

# %%
#7 Write a python program to read a file line by line and store it into a variable.
file_object = open("file.txt", 'w')
file_object.writelines('Hello \n Everyone \n welcome \n to \n tops\n')
file_object.close()
file_object = open("file.txt", 'r')
f = file_object.read()
print(f)

var = ''
for i in f:
  var += i

var
# Out:
# Hello
#  Everyone
#  welcome
#  to
#  tops
# 'Hello \n Everyone \n welcome \n to \n tops\n'

# %%
#8 #incomplete Write a pyhton program to find longest word.
file_object = open("file.txt", 'w')
file_object.write('Hello  Everyone  welcome  to  tops')
file_object.close()
file_object = open("file.txt", 'r')
f = file_object.readlines()
print(f)

a = max(f)

print(a)
# Out:
# ['Hello  Everyone  welcome  to  tops']
# Hello  Everyone  welcome  to  tops

# %%
file_object = open("file.txt", 'w')
file_object.writelines('Hello \n Everyone \n welcome \n to \n tops\n')
file_object.close()
file_object = open("file.txt", 'r')
data_read = file_object.read()
word = data_read.split()
a = len(word)
print(a)
# Out:
# 5

# %%
file = open('file.txt', 'r')
read_data = file.read()
per_word = read_data.split()

print('Total Words:', len(per_word))
# Out:
# Total Words: 5

# %%
#9 incomplete Program to count the number of lines in text file.
file_object = open("file.txt", 'w')
file_object.writelines('Hello \n Everyone\n welcome\n to \n tops \n')
file_object.close()
file_object = open("file.txt", 'r')
data = file_object.readline()
print(data)
data1 = len(data)     
print(data1)
# Out:
# ['Hello \n', ' Everyone\n', ' welcome\n', ' to \n', ' tops \n']
# 5
# Hello
#
# 7

# %%
#10 Program to count the frequency of words in a file.
file_object = open("file.txt", 'w')
file_object.writelines('Hello \n Everyone\n welcome\n to \n tops \n')
file_object.close()
file_object = open("file.txt", 'r')
data = file_object.read()
data1 = data.count('e')
print('Frequency of given word is  ' f'{data1}')
# Out:
# Frequency of given word is  5

# %%
#11 program to write a list to a file
lst = ["hello", "to", "world"]
textfile = open("file.txt", "w")
for element in lst:
    textfile.write(element +  '\n')
textfile.close()
textfile = open("file.txt", "r")
print(textfile.read())
# Out:
# hello
# to
# world

# %%
#11 Program to copy the content from one file to another

# %% [markdown]
# #12 Explain exception handling? What is error in Python?
#
# Ans - An exception is a Python object that represents an error. Python provides a way to handle the exception so that the code can be executed without any interruption. If we do not handle the exception, the interpreter doesn't execute all the code that exists after the exception.
#
#
# Errors are the problems in a program due to which the program will stop the execution. On the other hand, exceptions are raised when some internal events occur which changes the normal flow of the program. Two types of Error occurs in python. Syntax errors. Logical errors (Exceptions)

# %% [markdown]
# #13 How many except statements can a try- except block have? Name some in built eception classes.
#
# Ans - There has to be at least one except statement.
#
# AttributeError,IndexError,KeyError,NameError,RuntimeError,SyntaxError,IndentationError,TypeError etc are some in-built exception classes.

# %% [markdown]
# #14 When will the else part of try- except-else be executed?
#
# Ans - When no exception occurs then else part of try- except-else be executed.

# %% [markdown]
# #15 Can one block of except statements handle multiple exception?
#
# Ans - yes, like except TypeError, SyntaxError [,…].In Python, try-except blocks can be used to catch and respond to one or multiple exceptions. In cases where a process raises more than one possible exception, they can all be handled using a single except clause.

# %% [markdown]
# #16 When is finally block excecuted?
#
# Ans - Python provides a keyword finally, which is always executed after try and except blocks. The finally block always executes after normal termination of try block or after try block terminates due to some exception.

# %% [markdown]
# #17 What happens when '1' = 1 is executed?
#
# Ans -  It simply evaluates to false and does not raise any exception.

# %%
#18 How to you handle  Exceptions with try/except/finally in Python? Explain with coding snippets.
print('hello')

try:
  age = int(input('enter your age: '))
  print(age)
except ValueError as err:
  print('--error--', err)
finally:
  print('always run')
  
print('world')
# Out:
# hello
# enter your age: g
# --error-- invalid literal for int() with base 10: 'g'
# always run
# world

# %%
#19 Write pyhton program that user to enter only odd numbers,else will raise an exception.
try:
  n = int(input('Enter any number  '))
  if n % 2 != 0:
    print('Number is odd')
  else:
    raise Exception('Number is even')
except Exception :
 print('---error--- > Number is even')
# Out:
# Enter any number  4
# ---error--- > Number is even

# %% [markdown]
# #20 What are OOPS concept? Is multiple inheritance supported in java.
#
# Ans- Object-oriented programming is a model that provides different types of concepts, such as inheritance, abstraction, polymorphism, etc. These concepts aim to implement real-world entities in programs. They create working methods and variables to reuse them without compromising security.
#
# Java does not support multiple inheritance as it can give rise to problems in applications like the diamond problem. Java also does not support hybrid inheritance as it is a combination of one or more inheritance types and can ultimately turn into multiple inheritance.

# %% [markdown]
# #21 How to define a class in Python? What is self? Give an example of A pyhton class.
#
# Ans - A class is a user-defined blueprint or prototype from which objects are created. Classes provide a means of bundling data and functionality together. Creating a new class creates a new type of object, allowing new instances of that type to be made.
#
#
# The self parameter is a reference to the current instance of the class, and is used to access variables that belongs to the class.

# %%
class Human:
  def method(self):
    print('Human')

# %%
h = Human()
h.method()
# Out:
# Human

# %%
#22 Write a python class named rectangle constructed by a length and width and a method which will compute the area of a rectangle.

class Rectangle:
  def __init__(self, length , width):
    self.length = length
    self.width = width

  def area(self):
    return (self.length * self.width)

# %%
r = Rectangle(3,4)
r.area()
# Out:
# 12

# %%
#23 Write a python class named circle constructed by a radius and two method which will compute the area and the perimeter of a circle.
import math
class Circle:
  def __init__(self, radius):
    self.radius = radius
    

  def area(self):   
    return ( self.radius*self.radius* 3.14)

  def perimeter(self):   
    return ( self.radius*2* 3.14)

# %%
c = Circle(1)
c.area()
# Out:
# 3.14

# %%
c.perimeter()
# Out:
# 6.28

# %% [markdown]
# #24 Explain Inheritance in pyhton with an example? What is init? Or what is a Constructor in python?
#
# Ans - Inheritance is the procedure in which one class inherits the attributes and methods of another class. The class whose properties and methods are inherited is known as the Parent class. And the class that inherits the properties from the parent class is the Child class.
#
# ### Init -
# All classes have a function called __init__(), which is always executed when the class is being initiated.
#
# Use the __init__() function to assign values to object properties, or other operations that are necessary to do when the object is being created.
#
# ### Constructor -
# Constructors are generally used for instantiating an object. The task of constructors is to initialize(assign values) to the data members of the class when an object of the class is created. In Python the __init__() method is called the constructor and is always called when an object is created.

# %%
#Example of inheritance:

class Parent:
  def method_a(self):
    print('Parent class')

class Child(Parent):
  def method_2(self):
    print('child class')

# %%
c = Child()
c.method_a()
c.method_2()
# Out:
# Parent class
# child class

# %% [markdown]
# # 25 What is instantiation in terms of OOP terminology?
#
# Ans - Instantiation refers to creating an object/instance for a class.Instantiation − The creation of an instance of a class. Method − A special kind of function that is defined in a class definition. Object − A unique instance of a data structure that's defined by its class. An object comprises both data members (class variables and instance variables) and methods.

# %% [markdown]
# #26 What is used to check whether an object o is an instance of Class A?
#
# Ans - The Python's isinstance() function checks whether the object or variable is an instance of the specified class type or data type.
